# %% [markdown]
# Here's a grouping of the `pandas.read_excel()` parameters based on their functionality, along with their use cases:
#
# ### **1. File Input/Output**
# - **`io`**: The file path, Excel file object, or file-like object to read from.
#   - **Use Case**: Use when specifying the file or buffer from which to read the Excel data.
#
# ### **2. Sheet Selection**
# - **`sheet_name`**: Name(s) or index(es) of the sheet(s) to read.
#   - **Use Case**: Use when you need to specify which sheet(s) to read from a multi-sheet Excel file.
#
# ### **3. Header and Column Names**
# - **`header`**: Row number(s) to use as the column names.
#   - **Use Case**: Use when the Excel sheet has column headers in a specific row.
# - **`names`**: Custom column names.
#   - **Use Case**: Use when you want to manually specify the column names instead of using the default or provided ones in the file.
#
# ### **4. Indexing**
# - **`index_col`**: Column(s) to use as the index (row labels) of the DataFrame.
#   - **Use Case**: Use when you need to set one or more columns as the index of the DataFrame.
#
# ### **5. Column Selection**
# - **`usecols`**: Columns to read from the Excel file.
#   - **Use Case**: Use when you want to select only specific columns from the sheet.
#
# ### **6. Data Type Management**
# - **`dtype`**: Data type for data or columns.
#   - **Use Case**: Use when you need to enforce specific data types for columns during import.
# - **`dtype_backend`**: Backend to use for dtype conversion.
#   - **Use Case**: Use when you want to specify the backend (e.g., numpy, pandas) for handling data types.
#
# ### **7. Date Parsing**
# - **`parse_dates`**: Columns to parse as dates.
#   - **Use Case**: Use when certain columns should be parsed and interpreted as dates.
# - **`date_parser`**: Function to use for parsing dates.
#   - **Use Case**: Use when a custom date parsing function is required.
# - **`date_format`**: Format to use for parsing dates.
#   - **Use Case**: Use when the date format in the Excel file needs to be explicitly specified.
#
# ### **8. Converters and Custom Parsing**
# - **`converters`**: Custom functions to convert columns.
#   - **Use Case**: Use when you want to apply custom transformations or conversions to columns as they are imported.
#
# ### **9. Handling Missing Data**
# - **`na_values`**: Additional strings to recognize as NA/NaN.
#   - **Use Case**: Use when specific strings or values in the Excel file should be treated as missing data.
# - **`keep_default_na`**: Whether to include the default NaN values.
#   - **Use Case**: Use when deciding whether to include the standard missing values like `NA` or `NaN`.
# - **`na_filter`**: Detect missing values (NA values).
#   - **Use Case**: Use when controlling whether to filter out missing values during parsing.
#
# ### **10. Skipping Data**
# - **`skiprows`**: Rows to skip at the beginning.
#   - **Use Case**: Use when you need to skip certain rows at the start of the sheet.
# - **`skipfooter`**: Number of lines at the bottom to skip.
#   - **Use Case**: Use when there are extra rows at the end of the sheet that should not be included.
#
# ### **11. Row and Data Limits**
# - **`nrows`**: Number of rows to read.
#   - **Use Case**: Use when you want to limit the number of rows imported from the sheet.
#
# ### **12. Boolean Value Handling**
# - **`true_values`**: Strings to recognize as boolean True.
#   - **Use Case**: Use when specific strings should be interpreted as `True`.
# - **`false_values`**: Strings to recognize as boolean False.
#   - **Use Case**: Use when specific strings should be interpreted as `False`.
#
# ### **13. Numeric Parsing**
# - **`thousands`**: Character for thousands separator.
#   - **Use Case**: Use when a custom character is used in the Excel file to separate thousands (e.g., ',' or '.').
# - **`decimal`**: Character for decimal point.
#   - **Use Case**: Use when a custom character is used for the decimal point in numbers (e.g., ',' instead of '.').
#
# ### **14. Text Parsing**
# - **`comment`**: Character to indicate start of a comment.
#   - **Use Case**: Use when certain lines in the Excel file are comments and should be ignored.
#
# ### **15. Verbosity**
# - **`verbose`**: Whether to print additional information during parsing.
#   - **Use Case**: Use when you want more detailed output during the parsing process.
#
# ### **16. Storage Options**
# - **`storage_options`**: Extra options to pass to the storage backend.
#   - **Use Case**: Use when additional storage options are required for accessing remote or complex file paths.
#
# ### **17. Engine Configuration**
# - **`engine`**: Specifies the engine to use for parsing (e.g., 'xlrd', 'openpyxl').
#   - **Use Case**: Use when you want to select a specific engine for reading the Excel file.
# - **`engine_kwargs`**: Additional arguments to pass to the engine.
#   - **Use Case**: Use when there are specific configurations or parameters you need to pass to the engine used for reading the file.
#
# This grouping should help you understand how each parameter relates to different aspects of the `read_excel()` method's functionality.

# %% [markdown]
# Here are the two tables comparing the common and unique parameters between `read_csv` and `read_excel` in pandas, along with their use cases:
#
# ### **Table 1: Common Parameters in `read_csv` and `read_excel`**
#
# | **Parameter**       | **Functionality**                       | **Use Case**                                                                                                                                               |
# |---------------------|-----------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `header`            | Header and Column Names                 | Specifies row number(s) to use as column names. Useful when the header is not in the first row.                                                             |
# | `names`             | Header and Column Names                 | Manually specify column names instead of using the default or provided ones.                                                                                 |
# | `index_col`         | Indexing                                | Set one or more columns as the index (row labels) of the DataFrame.                                                                                          |
# | `usecols`           | Column Selection                        | Select specific columns to read from the file/sheet.                                                                                                         |
# | `dtype`             | Data Type Management                    | Enforce specific data types for columns during import.                                                                                                       |
# | `converters`        | Converters and Custom Parsing           | Apply custom functions to convert data in specific columns as they are imported.                                                                              |
# | `true_values`       | Boolean Value Handling                  | Specify strings to be recognized as boolean True.                                                                                                            |
# | `false_values`      | Boolean Value Handling                  | Specify strings to be recognized as boolean False.                                                                                                           |
# | `skiprows`          | Skipping Data                           | Skip specific rows at the beginning of the file/sheet.                                                                                                       |
# | `nrows`             | Row and Data Limits                     | Limit the number of rows imported.                                                                                                                           |
# | `na_values`         | Handling Missing Data                   | Specify additional strings to recognize as NA/NaN.                                                                                                           |
# | `keep_default_na`   | Handling Missing Data                   | Determine whether to include the default NaN values (`NA`, `NaN`, etc.).                                                                                      |
# | `na_filter`         | Handling Missing Data                   | Control whether to filter out missing values during parsing.                                                                                                  |
# | `skipfooter`        | Skipping Data                           | Skip a specific number of lines at the bottom of the file/sheet.                                                                                              |
# | `parse_dates`       | Date Parsing                            | Parse specific columns as dates.                                                                                                                              |
# | `date_parser`       | Date Parsing                            | Apply a custom date parsing function.                                                                                                                         |
# | `date_format`       | Date Parsing                            | Specify the format for date parsing.                                                                                                                          |
# | `thousands`         | Numeric Parsing                         | Specify the character used for thousands separators.                                                                                                          |
# | `decimal`           | Numeric Parsing                         | Specify the character used for decimal points in numeric data.                                                                                                |
# | `comment`           | Text Parsing                            | Indicate the character that denotes the start of a comment, which should be ignored during parsing.                                                           |
# | `storage_options`   | Storage Options                         | Provide additional options to pass to the storage backend when accessing remote or complex file paths.                                                        |
#
# ### **Table 2: Unique Parameters in `read_csv` and `read_excel`**
#
# | **Method** | **Parameter**       | **Functionality**                | **Use Case**                                                                                                                                               |
# |------------|---------------------|----------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `read_csv` | `sep`               | Separator/Delimiter              | Defines the delimiter used to separate fields in the CSV file.                                                                                               |
# | `read_csv` | `delimiter`         | Separator/Delimiter              | Alternative to `sep`, allows specifying the delimiter.                                                                                                        |
# | `read_csv` | `lineterminator`    | Text Parsing                     | Specifies the character to break lines.                                                                                                                      |
# | `read_csv` | `quotechar`         | Text Parsing                     | Defines the character used for quoting fields.                                                                                                               |
# | `read_csv` | `quoting`           | Text Parsing                     | Controls field quoting behavior (e.g., `QUOTE_MINIMAL`, `QUOTE_ALL`).                                                                                        |
# | `read_csv` | `doublequote`       | Text Parsing                     | Specifies whether to double-quote inside quoted fields.                                                                                                       |
# | `read_csv` | `escapechar`        | Text Parsing                     | Character used to escape delimiter or quote characters within fields.                                                                                         |
# | `read_csv` | `encoding`          | Encoding                         | Specifies the character encoding for the CSV file (e.g., 'utf-8').                                                                                            |
# | `read_csv` | `encoding_errors`   | Encoding                         | Controls how encoding errors are handled.                                                                                                                     |
# | `read_csv` | `dialect`           | Dialect                          | Specifies the CSV dialect (e.g., 'excel', 'unix').                                                                                                            |
# | `read_csv` | `on_bad_lines`      | Error Handling                   | Specifies how to handle lines with errors (e.g., 'skip', 'warn', 'error').                                                                                     |
# | `read_csv` | `delim_whitespace`  | Whitespace Handling              | Specifies whether to use whitespace as the delimiter instead of a specific character.                                                                         |
# | `read_csv` | `verbose`           | Verbosity                        | Controls whether to output additional information during parsing.                                                                                             |
# | `read_csv` | `iterator`          | Iterator/Chunking                | Returns an iterator instead of a DataFrame, allowing processing of large files in smaller chunks.                                                             |
# | `read_csv` | `chunksize`         | Iterator/Chunking                | Specifies the number of lines to read per chunk, allowing large files to be processed in chunks.                                                              |
# | `read_csv` | `compression`       | Compression                      | Specifies the compression mode (e.g., 'gzip', 'bz2', 'zip').                                                                                                  |
# | `read_csv` | `low_memory`        | Memory Management                | Internally processes the file in chunks to reduce memory usage.                                                                                               |
# | `read_csv` | `memory_map`        | Memory Management                | Uses a memory map to read the file, which can improve performance for large files.                                                                             |
# | `read_csv` | `float_precision`   | Numeric Parsing                  | Controls the precision of floating-point numbers (e.g., 'high', 'legacy').                                                                                     |
# | `read_excel` | `io`              | File Input/Output                | Specifies the file path, Excel file object, or file-like object to read from.                                                                                 |
# | `read_excel` | `sheet_name`      | Sheet Selection                  | Specifies the sheet name(s) or index(es) to read from in a multi-sheet Excel file.                                                                             |
# | `read_excel` | `engine`          | Engine Configuration             | Specifies the engine to use for parsing the Excel file (e.g., 'xlrd', 'openpyxl').                                                                             |
# | `read_excel` | `engine_kwargs`   | Engine Configuration             | Allows passing additional arguments to the engine used for reading the Excel file.                                                                             |
#
# These tables organize the common and unique parameters of `read_csv` and `read_excel`, making it easier to understand which functionalities overlap and which are specific to each method.
